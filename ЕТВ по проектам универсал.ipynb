# %%
import pandas as pd
import pymysql
import gspread 
from oauth2client.service_account import ServiceAccountCredentials
import datetime
import os
from datetime import datetime, timedelta
import glob
from datetime import datetime
from clickhouse_driver import Client
import re

# %%
path_to_credential = r'C:\Users\Guest\Downloads\вспомогательные файлы\quotas-338711-1e6d339f9a93.json' 

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(path_to_credential, scope)
gs = gspread.authorize(credentials)

table_name4 = 'Группировка очередей'

work_sheet4 = gs.open(table_name4)
sheet4 = work_sheet4.worksheet('Лист1')
data4 = sheet4.get_all_values() 
headers4 = data4.pop(0) 
step = pd.DataFrame(data4, columns=headers4)


#  tab = df.merge(step, left_on = 'dialog', right_on = 'Очередь', how = 'left').fillna('')
step = step[step['Группировка'].str.contains('УНИВЕРСАЛ', case=False)]
step[['Очередь']]=step[['Очередь']].astype('int64')
step = step['Очередь']
step = step.tolist()

# %%
df = pd.DataFrame()
queue_list = step
k = 0

for queue in queue_list:
    print(f' Очередь {queue}, Выгрузка {k}')
    sql = f'''select distinct jc_robot_log.phone,
                         date(call_date)                       calldate,
                         jc_robot_log.assigned_user_id,
                         substring(jc_robot_log.dialog, 11, 4) dialog,
                         client_status,
                         last_step,
                         was_repeat,
                         if(contacts_cstm.city_c is null or contacts_cstm.city_c = '' or contacts_cstm.city_c = 0,
                            concat(town_c, '_t'),
                            contacts_cstm.city_c)              city_c,
                         if(house is null, 0, 1)               etv,
                         providers
         from suitecrm_robot.jc_robot_log
                  left join address_log al on jc_robot_log.dialog = al.dialog and al.phone = jc_robot_log.phone AND
                                              date(calldate) = date(call_date)
                  left join suitecrm.contacts
                            on jc_robot_log.phone = phone_work
                  left join suitecrm.contacts_cstm on contacts.id = id_c
         where last_step not in ('', '0', '1', '261', '262', '111', '361', '362', '371', '372')
           and date(call_date) = date(now()) - interval 1 day
           and (inbound_call = 0 or inbound_call = '')
             and substring(jc_robot_log.dialog,11,4) = {queue}
    '''

    Con = pymysql.Connect(host="192.168.1.183", user="base_dep_slave", passwd="IyHBh9mDBdpg", db="suitecrm",
                      charset='utf8')
    
    
    robot = pd.read_sql_query(sql, Con)
    df = df.append(robot)
    k += 1
# Out:
#  Очередь 9003, Выгрузка 0
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9017, Выгрузка 1
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
#  Очередь 9020, Выгрузка 2
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9021, Выгрузка 3
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
#  Очередь 9028, Выгрузка 4
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9040, Выгрузка 5
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9087, Выгрузка 6
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9098, Выгрузка 7
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9099, Выгрузка 8
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9121, Выгрузка 9
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9126, Выгрузка 10
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9130, Выгрузка 11
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9131, Выгрузка 12
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9137, Выгрузка 13
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
#  Очередь 9138, Выгрузка 14
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9140, Выгрузка 15
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9154, Выгрузка 16
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9157, Выгрузка 17
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9162, Выгрузка 18
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
#  Очередь 9168, Выгрузка 19
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
#  Очередь 9169, Выгрузка 20
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9171, Выгрузка 21
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9174, Выгрузка 22
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9176, Выгрузка 23
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9178, Выгрузка 24
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9179, Выгрузка 25
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
#  Очередь 9183, Выгрузка 26
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9184, Выгрузка 27
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9185, Выгрузка 28
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9196, Выгрузка 29
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9217, Выгрузка 30
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9229, Выгрузка 31
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
#  Очередь 9263, Выгрузка 32
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9265, Выгрузка 33
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
#  Очередь 9267, Выгрузка 34
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   robot = pd.read_sql_query(sql, Con)
#  Очередь 9270, Выгрузка 35
# C:\Users\Guest\AppData\Local\Temp\ipykernel_26416\1461887581.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(robot)

# %%
df['providers'] = df['providers'].str.split(',')
df = df.explode('providers')
df = df.fillna('').astype('str')

# df = df.groupby(['calldate',
#                  'assigned_user_id',
#                  'dialog',
#                  'client_status',
#                  'last_step',
#                  'was_repeat',
#                  'city_c',
#                  'etv',
#                  'providers'], as_index=False, dropna=False).agg({'phone': 'count'})

path_to_credential = r'C:\Users\Guest\Downloads\вспомогательные файлы\quotas-338711-1e6d339f9a93.json' 

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(path_to_credential, scope)
gs = gspread.authorize(credentials)

table_name4 = 'Группировка очередей'

work_sheet4 = gs.open(table_name4)
sheet4 = work_sheet4.worksheet('Лист1')
data4 = sheet4.get_all_values() 
headers4 = data4.pop(0) 
step = pd.DataFrame(data4, columns=headers4)


tab = df.merge(step, left_on = 'dialog', right_on = 'Очередь', how = 'left').fillna('')
tab = tab[tab['Группировка'].str.contains('УНИВЕРСАЛ', case=False)]

# %%
tab=tab.astype('str')
tab['providers2']=''

def update_providers(row):
    if row['providers'] == '3':
        row['providers2'] = 'DOMRU'
    elif row['providers'] == '5':
        row['providers2'] = 'RTK'
    elif row['providers'] == '6':
        row['providers2'] = 'TTK'
    elif row['providers'] == '10':
        row['providers2'] = 'BEELINE'
    elif row['providers'] == '11':
        row['providers2'] = 'MTS'
    elif row['providers'] == '19':
        row['providers2'] = 'NBN'
    elif row['providers'] == '14':
        row['providers2'] = '2COM'  
    elif row['providers'] == '211':
        row['providers2'] = 'TAT'
    else:
        row['providers2'] = ''
        
        
tab.apply(lambda row: update_providers(row), axis=1)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 101977    None
# 101978    None
# 101979    None
# 101980    None
# 101981    None
# Length: 101982, dtype: object

# %%
tab.loc[tab['project_users'] != '']
# Out:
#           calldate                      assigned_user_id dialog client_status  \
# 16      2024-05-13  413ce22e-1750-f400-fdfd-65e73dbcf36d   9021      refusing
# 102     2024-05-13  73827bfc-c172-812c-a345-64eee7332ac2   9021      refusing
# 204     2024-05-13  607272d7-0d5d-5836-4aaa-615eee16a460   9021      refusing
# 205     2024-05-13  607272d7-0d5d-5836-4aaa-615eee16a460   9021      refusing
# 206     2024-05-13  607272d7-0d5d-5836-4aaa-615eee16a460   9021      refusing
# ...            ...                                   ...    ...           ...
# 101687  2024-05-13  191464bb-a2a5-28d7-2a44-662aa9ff292f   9270      refusing
# 101688  2024-05-13  1a3aad3d-eb35-2f42-6ef7-65e5cbea8f5b   9270      refusing
# 101764  2024-05-13  40755418-e60e-7b99-5048-6511360fb54c   9270      refusing
# 101927  2024-05-13  d3366e6f-707d-3db3-e1d1-656ee4756f0a   9270      refusing
# 101938  2024-05-13  1c721e32-c07d-8131-1d43-662aa8e31950   9270      refusing
#
#        last_step was_repeat city_c etv providers        phone project_log  \
# 16           340          1    955   1            89028743899    MTS LIDS
# 102           91          1    971   1         5  89501960876    MTS LIDS
# 204           91          1    967   1         5  89506517784    MTS LIDS
# 205           91          1    967   1         3  89506517784    MTS LIDS
# 206           91          1    967   1        11  89506517784    MTS LIDS
# ...          ...        ...    ...  ..       ...          ...         ...
# 101687       340          1   1147   1            89912876512         MTS
# 101688        91          1    398   1         5  89680691479         MTS
# 101764       340          1   1147   1            89252148888         MTS
# 101927       340          0   1147   0            89309308010         MTS
# 101938       340          1    683   1            89153276611         MTS
#
#        project_address    project_users
# 16                      GULFSTREAM LIDS
# 102                RTK         RTK LIDS
# 204                RTK         RTK LIDS
# 205              DOMRU         RTK LIDS
# 206                MTS         RTK LIDS
# ...                ...              ...
# 101687                  GULFSTREAM LIDS
# 101688             RTK         RTK LIDS
# 101764                  GULFSTREAM LIDS
# 101927                       GULFSTREAM
# 101938                  GULFSTREAM LIDS
#
# [2593 rows x 13 columns]

# %%
path_to_credential = r'C:\Users\Guest\Downloads\вспомогательные файлы\quotas-338711-1e6d339f9a93.json' 

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(path_to_credential, scope)
gs = gspread.authorize(credentials)

table_name4 = 'Команды/Проекты'

work_sheet4 = gs.open(table_name4)
sheet4 = work_sheet4.worksheet('Лиды')
data4 = sheet4.get_all_values() 
headers4 = data4.pop(0) 
lids = pd.DataFrame(data4, columns=headers4)


path_to_credential = r'C:\Users\Guest\Downloads\вспомогательные файлы\quotas-338711-1e6d339f9a93.json' 
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(path_to_credential, scope)
gs = gspread.authorize(credentials)

table_name4 = 'Команды/Проекты'

work_sheet4 = gs.open(table_name4)
sheet4 = work_sheet4.worksheet('JC')
data4 = sheet4.get_all_values() 
headers4 = data4.pop(0) 
jc = pd.DataFrame(data4, columns=headers4)

# %%
users = pd.read_csv(r'\\192.168.1.157\dbs\scripts fsp\Current Files\Пользователи.csv',  sep=',', encoding='utf-8').astype('str').fillna('')


tab = tab.merge(users[['id','supervisor']], left_on = 'assigned_user_id', right_on = 'id', how = 'left').fillna('')
tab =  tab.merge(lids[['Проект','СВ CRM']], left_on = 'supervisor', right_on = 'СВ CRM', how = 'left').fillna('')
tab =  tab.merge(jc[['Проект','CRM СВ']], left_on = 'supervisor', right_on = 'CRM СВ', how = 'left').fillna('')
tab = tab.astype('str')

# %%
def update_project(row):
    if row['Проект_x'] == '':
        row['Проект_x'] = row['Проект_y']
    else:
        row['Проект_x']
tab.apply(lambda row: update_project(row), axis=1)
tab['phone']=tab['phone'].astype('int64')

# %%
tab = tab[['calldate',
           'assigned_user_id',
           'dialog',
           'client_status',
           'last_step',
           'was_repeat',
           'city_c','etv',
           'providers','phone',
           'Проект (набирающая очередь)',
           'providers2','Проект_x']].rename(columns={'providers2': 'project_address',
                         'Проект (набирающая очередь)': 'project_log',
                         'Проект_x': 'project_users'})

# %%
csv_files = glob.glob('//192.168.1.157/dbs/scripts fsp/Current Files/Проект/Шаги/*.csv')
dataframes  = []

for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

steps = pd.concat(dataframes)

# %%
steps['step'] = steps['step'].astype('str').apply(lambda x: x.replace('.0',''))
steps['ochered'] = steps['ochered'].astype('str').apply(lambda x: x.replace('.0',''))
steps['type_steps'] = steps['type_steps'].astype('str').apply(lambda x: x.replace('.0',''))

# %%
tab['perevod'] = ''
tab = tab.merge(steps, left_on = ['calldate','dialog','last_step'], right_on = ['date','ochered','step'], how = 'left').fillna('')
print('Цепим переводы')
       
def check_1(row):
    if row['type_steps'] == '1':
        return '1'
    else:
        return '0'
tab['perevod'] = tab.apply(check_1, axis=1)
# Out:
# Цепим переводы

# %%
tab=tab[['calldate',
           'assigned_user_id',
           'dialog',
           'client_status',
           'last_step',
           'was_repeat',
           'city_c','etv',
           'providers','phone','project_log','project_address','project_users','perevod']]

# %%
client = Client(host='192.168.1.99', port='9000', user='default', password='jdfwl6812hwe',
                database='suitecrm_robot_ch', settings={'use_numpy': True})
        
        
client.insert_dataframe('INSERT INTO suitecrm_robot_ch.etv_universal VALUES', tab)
# Out:
# 11872430

# %%
tab = pd.read_csv(r'\\192.168.1.157\dbs\scripts fsp\Current Files\ЕТВ\ЕТВ февраль 2023.csv',  sep=',', encoding='utf-8').fillna('')
# Out:
# C:\Users\Guest\AppData\Local\Temp\ipykernel_9068\1449295819.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   tab = pd.read_csv(r'\\192.168.1.157\dbs\scripts fsp\Current Files\ЕТВ\ЕТВ февраль 2023.csv',  sep=',', encoding='utf-8').fillna('')

# %%
tab.dtypes
# Out:
# calldate            object
# assigned_user_id    object
# dialog               int64
# client_status       object
# last_step            int64
# was_repeat           int64
# city_c              object
# etv                  int64
# providers           object
# phone                int64
# project_log         object
# project_address     object
# project_users       object
# perevod              int64
# dtype: object

# %%
tab[['calldate','assigned_user_id','dialog','client_status','last_step',
     'was_repeat','city_c','etv','providers','project_log','project_address',
     'project_users','perevod']]=tab[['calldate','assigned_user_id','dialog','client_status','last_step',
     'was_repeat','city_c','etv','providers','project_log','project_address',
     'project_users','perevod']].astype('str')

# %%
tab[['phone']] = tab[['phone']].astype('int64')
